# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('synthetic_logs.csv')

# %%
data.head()
# Out:
#    timestamp           source  \
# 0  timestamp        ModernCRM
# 1  timestamp        ModernCRM
# 2  timestamp  AnalyticsEngine
# 3  timestamp         ModernHR
# 4  timestamp    BillingSystem
#
#                                          log_message    target_label  \
# 0  nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1     Email service experiencing issues with sending  Critical Error
# 2          Unauthorized access to data was attempted  Security Alert
# 3  nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4  nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
#
#   complexity  Unnamed: 5 Unnamed: 6
# 0       bert         NaN        NaN
# 1       bert         NaN        NaN
# 2       bert         NaN        NaN
# 3       bert         NaN        NaN
# 4       bert         NaN        NaN

# %%
data['complexity'].unique()
# Out:
# <StringArray>
# ['bert', 'regex', 'llm']
# Length: 3, dtype: str

# %%
data['source'].unique()
# Out:
# <StringArray>
# [      'ModernCRM', 'AnalyticsEngine',        'ModernHR',   'BillingSystem',
#    'ThirdPartyAPI',       'LegacyCRM']
# Length: 6, dtype: str

# %%
data['log_message'].head(30)
# Out:
# 0     nova.osapi_compute.wsgi.server [req-b9718cd8-f...
# 1        Email service experiencing issues with sending
# 2             Unauthorized access to data was attempted
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b...
# 4     nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...
# 5     nova.osapi_compute.wsgi.server [req-f0bffbc3-5...
# 6             Shard 6 replication task ended in failure
# 7     File data_6169.csv uploaded successfully by us...
# 8     nova.compute.claims [req-a07ac654-8e81-416d-bf...
# 9     nova.osapi_compute.wsgi.server [req-2bf7cfee-a...
# 10             Email server encountered a sending fault
# 11      Critical system unit error: unit ID Component55
# 12    nova.osapi_compute.wsgi.server [req-d4f8d0c2-4...
# 13    Multiple bad login attempts detected on user 8...
# 14    File data_3847.csv uploaded successfully by us...
# 15                       Backup completed successfully.
# 16    nova.osapi_compute.wsgi.server [req-6fe0e366-f...
# 17    nova.osapi_compute.wsgi.server [req-5f1c2027-e...
# 18             Account with ID 5351 created by User634.
# 19    nova.osapi_compute.wsgi.server [req-945d1f31-a...
# 20    nova.osapi_compute.wsgi.server [req-033d97b9-6...
# 21    nova.osapi_compute.wsgi.server [req-75bc6269-8...
# 22    nova.compute.resource_tracker [req-addc1839-2e...
# 23    nova.osapi_compute.wsgi.server [req-077c3c87-b...
# 24    nova.osapi_compute.wsgi.server [req-4e83daf7-a...
# 25    nova.osapi_compute.wsgi.server [req-bfce366e-9...
# 26    nova.compute.claims [req-d6986b54-3735-4a42-90...
# 27                             User User685 logged out.
# 28    nova.osapi_compute.wsgi.server [req-5e6e042b-f...
# 29    Alert: brute force login attempt from 192.168....
# Name: log_message, dtype: str

# %%
data['timestamp'].head(10)
# Out:
# 0    timestamp
# 1    timestamp
# 2    timestamp
# 3    timestamp
# 4    timestamp
# 5    timestamp
# 6    timestamp
# 7    timestamp
# 8    timestamp
# 9    timestamp
# Name: timestamp, dtype: str

# %% [markdown]
# 1-timestamp sahi kro \
# 2- regex pattern\
# 3-bert classification\
# 4-llm classification

# %%
data['target_label'].unique()
# Out:
# <StringArray>
# [        'HTTP Status',      'Critical Error',      'Security Alert',
#                'Error', 'System Notification',      'Resource Usage',
#          'User Action',      'Workflow Error', 'Deprecation Warning']
# Length: 9, dtype: str

# %%
data[data['target_label'] == 'HTTP Status']
# Out:
#              timestamp         source  \
# 0            timestamp      ModernCRM
# 3            timestamp       ModernHR
# 4            timestamp  BillingSystem
# 5            timestamp       ModernHR
# 9            timestamp       ModernHR
# ...                ...            ...
# 2399  08-03-2025 06:23  ThirdPartyAPI
# 2401  05-12-2025 15:51      ModernCRM
# 2404  18-09-2025 02:18  ThirdPartyAPI
# 2405  13-08-2025 07:29       ModernHR
# 2407  03-08-2025 03:07  ThirdPartyAPI
#
#                                             log_message target_label  \
# 0     nova.osapi_compute.wsgi.server [req-b9718cd8-f...  HTTP Status
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b...  HTTP Status
# 4     nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...  HTTP Status
# 5     nova.osapi_compute.wsgi.server [req-f0bffbc3-5...  HTTP Status
# 9     nova.osapi_compute.wsgi.server [req-2bf7cfee-a...  HTTP Status
# ...                                                 ...          ...
# 2399  nova.metadata.wsgi.server [req-ba29717b-249a-4...  HTTP Status
# 2401  nova.osapi_compute.wsgi.server [req-4bdf00b0-3...  HTTP Status
# 2404  nova.osapi_compute.wsgi.server [req-2c9c783f-3...  HTTP Status
# 2405  nova.osapi_compute.wsgi.server [req-96c3ec98-2...  HTTP Status
# 2407  nova.metadata.wsgi.server [req-b6d4a270-accb-4...  HTTP Status
#
#      complexity  Unnamed: 5 Unnamed: 6
# 0          bert         NaN        NaN
# 3          bert         NaN        NaN
# 4          bert         NaN        NaN
# 5          bert         NaN        NaN
# 9          bert         NaN        NaN
# ...         ...         ...        ...
# 2399       bert         NaN        NaN
# 2401       bert         NaN        NaN
# 2404       bert         NaN        NaN
# 2405       bert         NaN        NaN
# 2407       bert         NaN        NaN
#
# [1017 rows x 7 columns]

# %%
reg_data=data[data['complexity']=='regex']

# %%
reg_data['target_label'].unique()
# Out:
# <StringArray>
# ['System Notification', 'User Action']
# Length: 2, dtype: str

# %%
data[data['target_label'] == 'HTTP Status'].iloc[0]['log_message']
# Out:
# 'nova.osapi_compute.wsgi.server [req-b9718cd8-f65e-49cc-8349-6cf7122af137 113d3a99c3da401fbd62cc2caa5b96d2 54fadb412c4e40cdbaed9335e4c35a9e - - -] 10.11.10.1 "GET /v2/54fadb412c4e40cdbaed9335e4c35a9e/servers/detail HTTP/1.1" status: 200 len: 1893 time: 0.2675118'

# %%
reg_data[reg_data['target_label'] == 'System Notification']
# Out:
#              timestamp           source  \
# 7            timestamp         ModernHR
# 14           timestamp    ThirdPartyAPI
# 15           timestamp        ModernCRM
# 30      4/26/2025 7:54  AnalyticsEngine
# 36    11/19/2025 13:14    BillingSystem
# ...                ...              ...
# 2376    6/27/2025 8:47        ModernCRM
# 2381  09-05-2025 06:39    ThirdPartyAPI
# 2394  04-03-2025 13:13         ModernHR
# 2395  05-02-2025 14:29    ThirdPartyAPI
# 2403  10-01-2025 01:31        ModernCRM
#
#                                             log_message         target_label  \
# 7     File data_6169.csv uploaded successfully by us...  System Notification
# 14    File data_3847.csv uploaded successfully by us...  System Notification
# 15                       Backup completed successfully.  System Notification
# 30               Backup started at 2025-05-14 07:06:55.  System Notification
# 36             System reboot initiated by user User243.  System Notification
# ...                                                 ...                  ...
# 2376                   System updated to version 2.0.5.  System Notification
# 2381               Disk cleanup completed successfully.  System Notification
# 2394               Disk cleanup completed successfully.  System Notification
# 2395               Backup ended at 2025-05-06 11:23:16.  System Notification
# 2403                     Backup completed successfully.  System Notification
#
#      complexity  Unnamed: 5 Unnamed: 6
# 7         regex         NaN        NaN
# 14        regex         NaN        NaN
# 15        regex         NaN        NaN
# 30        regex         NaN        NaN
# 36        regex         NaN        NaN
# ...         ...         ...        ...
# 2376      regex         NaN        NaN
# 2381      regex         NaN        NaN
# 2394      regex         NaN        NaN
# 2395      regex         NaN        NaN
# 2403      regex         NaN        NaN
#
# [356 rows x 7 columns]

# %%
reg_data[~reg_data["log_message"].str.contains("backup", case=False, na=False)]
# Out:
#              timestamp         source  \
# 7            timestamp       ModernHR
# 14           timestamp  ThirdPartyAPI
# 18           timestamp      ModernCRM
# 27           timestamp  ThirdPartyAPI
# 36    11/19/2025 13:14  BillingSystem
# ...                ...            ...
# 2364  04-05-2025 10:28      ModernCRM
# 2368  12/13/2025 20:04  ThirdPartyAPI
# 2376    6/27/2025 8:47      ModernCRM
# 2381  09-05-2025 06:39  ThirdPartyAPI
# 2394  04-03-2025 13:13       ModernHR
#
#                                             log_message         target_label  \
# 7     File data_6169.csv uploaded successfully by us...  System Notification
# 14    File data_3847.csv uploaded successfully by us...  System Notification
# 18             Account with ID 5351 created by User634.          User Action
# 27                             User User685 logged out.          User Action
# 36             System reboot initiated by user User243.  System Notification
# ...                                                 ...                  ...
# 2364                   System updated to version 2.7.8.  System Notification
# 2368               Disk cleanup completed successfully.  System Notification
# 2376                   System updated to version 2.0.5.  System Notification
# 2381               Disk cleanup completed successfully.  System Notification
# 2394               Disk cleanup completed successfully.  System Notification
#
#      complexity  Unnamed: 5 Unnamed: 6
# 7         regex         NaN        NaN
# 14        regex         NaN        NaN
# 18        regex         NaN        NaN
# 27        regex         NaN        NaN
# 36        regex         NaN        NaN
# ...         ...         ...        ...
# 2364      regex         NaN        NaN
# 2368      regex         NaN        NaN
# 2376      regex         NaN        NaN
# 2381      regex         NaN        NaN
# 2394      regex         NaN        NaN
#
# [354 rows x 7 columns]
